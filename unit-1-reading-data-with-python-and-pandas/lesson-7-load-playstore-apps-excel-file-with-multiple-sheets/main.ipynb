# %%
'''
# Load different sheets from PlayStore Apps dataset

Using the `playstore.xlsx` Excel file from the given `data_url` and:

- Save in a `playstore_df` variable the `Google_playstore` sheet. Use the first column as index.
- Save in a `content_id_df` variable the `Content_ID` sheet. Use `Content_ID` as index.

> This files originated as a CSV from Kaggle and has been altered for this course, https://www.kaggle.com/lava18/google-play-store-apps
'''
import numpy as np
import pandas as pd

data_url = 'https://github.com/ine-rmotr-projects/project-files/files/4086772/playstore.xlsx'

# %%
#read file and get all the sheet name 
excelfile= pd.ExcelFile(data_url)
sheets = excelfile.sheet_names
sheets
# Out:
# ['Google_playstore', 'Content_ID']

# %%
cols = excelfile.parse(sheet_name=sheets[0], nrows=1).columns
cols[1:]
# Out:
# Index(['App', 'Category', 'Rating', 'Installs', 'Type', 'Price', 'Content_ID',
#        'Genres', 'Last_Updated'],
#       dtype='object')

# %%
#try read sheet 1 
apps = excelfile.parse(sheet_name=sheets[0])#, usecols= cols[1:],index_col=None, converters = {"Content_ID": np.int16} ,parse_dates = [-1])

apps.head(10)
#apps.info()
# Out:
#    Unnamed: 0                                                App  \
# 0         0.0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1         1.0                                Coloring book moana
# 2         2.0  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3         3.0                              Sketch - Draw & Paint
# 4         4.0              Pixel Draw - Number Art Coloring Book
# 5         5.0                         Paper flowers instructions
# 6         6.0            Smoke Effect Photo Maker - Smoke Editor
# 7         7.0                                   Infinite Painter
# 8         8.0                               Garden Coloring Book
# 9         9.0                      Kids Paint Free - Drawing Fun
#
#          Category  Rating     Installs  Type Price  Content_ID  \
# 0  ART_AND_DESIGN     4.1      10,000+  Free     0       101.0
# 1  ART_AND_DESIGN     3.9     500,000+  Free     0       101.0
# 2  ART_AND_DESIGN     4.7   5,000,000+  Free     0       101.0
# 3  ART_AND_DESIGN     4.5  50,000,000+  Free     0       102.0
# 4  ART_AND_DESIGN     4.3     100,000+  Free     0       101.0
# 5  ART_AND_DESIGN     4.4      50,000+  Free     0       101.0
# 6  ART_AND_DESIGN     3.8      50,000+  Free     0       101.0
# 7  ART_AND_DESIGN     4.1   1,000,000+  Free     0       101.0
# 8  ART_AND_DESIGN     4.4   1,000,000+  Free     0       101.0
# 9  ART_AND_DESIGN     4.7      10,000+  Free     0       101.0
#
#                       Genres        Last_Updated
# 0               Art & Design     January 7, 2018
# 1  Art & Design;Pretend Play    January 15, 2018
# 2               Art & Design      August 1, 2018
# 3               Art & Design        June 8, 2018
# 4    Art & Design;Creativity       June 20, 2018
# 5               Art & Design      March 26, 2017
# 6               Art & Design      April 26, 2018
# 7               Art & Design       June 14, 2018
# 8               Art & Design  September 20, 2017
# 9    Art & Design;Creativity        July 3, 2018
